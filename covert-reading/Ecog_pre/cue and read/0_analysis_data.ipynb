# %% [markdown]
# # Load data and concanate each word to one block

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
import os
import sys
sys.path.append('../')
from ecog_band.utils import *
import pandas as pd
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report, confusion_matrix
import torch
from torch.utils import data as Data
from sklearn.model_selection import GridSearchCV,train_test_split
import torch.nn as nn
import seaborn as sns
from matplotlib.colors import Normalize
from matplotlib.patches import Rectangle
import scipy.io as scio
import matplotlib.image as mpimg
import matplotlib as mpl
import matplotlib.patches as patches
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

bands_list = ['theta', 'alpha', 'beta1', 'beta2', 'low gamma', 'high gamma']
freq_list=[400]
HS_list=[68, 69, 75, 79, 82, 83, 84, 85, 86]
mpl.rcParams['font.size'] =10

# %%
import numpy as np
import os

def process_and_save_data(HS_list, freq_list, bands_list, base_path, save_path):
    """
    处理 ECoG 数据并保存为任务相关格式。
    
    参数:
    - HS_list: list，被试列表
    - freq_list: list，频段列表
    - bands_list: list，band 列表
    - base_path: str，数据存储基础路径
    - save_path: str，结果保存路径
    """
    keys = ['功课', '力果', '宫客', '作业', 'gōng kè', '树叶', '对十', '数页', '绿草', 'shù yè']
    
    # 确保保存路径存在
    os.makedirs(save_path, exist_ok=True)
    
    for HS in HS_list:
        for freq in freq_list:
            cue_data_dict = {}
            read_data_dict = {}

            for band in bands_list:
                cue_trials = []
                read_trials = []
                # 加载每个 band 的 block 数据
                file_path = os.path.join(base_path, f"HS{HS}block_{band}.npy")
                block_data = np.load(file_path, allow_pickle=True).item()

                # 处理 cue 数据
                for key in keys:
                    if key in block_data:
                        data = block_data[key]  # data 是一个长度为 256 的列表，每个元素 shape 为 (time2200, trials)
                        reshaped_data = np.array([elec_data.T for elec_data in data])  # (electrodes, trials, time)
                        reshaped_data = reshaped_data.transpose(1, 0, 2)  # (trials, electrodes, time)
                        start = int(1*400 - 0.2*400)
                        cue_trials.append(reshaped_data[:, :, int(start):int(start+0.95*freq)])
                        read_trials.append(reshaped_data[:, :, int(start+2*freq):int(start+2*freq+0.95*freq)])
                
                # 合并所有 trials
                if cue_trials:
                    cue_trials = np.concatenate(cue_trials, axis=0)  # 合并所有 (trials, electrodes, time_steps)
                if read_trials:
                    read_trials = np.concatenate(read_trials, axis=0)

                print(f'cue trails shape for {band}: {cue_trials.shape}, cue trails shape for band{band}: {read_trials.shape}')
                
                # 存储处理好的数据到对应字典
                cue_data_dict[band] = cue_trials
                read_data_dict[band] = read_trials

            # 保存每个频段的数据
            os.makedirs(os.path.join(save_path, f'HS{HS}'), exist_ok=True)
            np.save(os.path.join(save_path, f"HS{HS}/cue_allbands_{freq}hz.npy"), cue_data_dict)
            np.save(os.path.join(save_path, f"HS{HS}/read_allbands_{freq}hz.npy"), read_data_dict)

            print(f"Processed and saved data for HS{HS}, freq {freq}")

# %%
base_path = '/public/DATA/overt_reading/Blocked_data/'  # 数据基础路径
save_path = '/public/DATA/overt_reading/aligned_data/'  # 数据保存路径

# 调用数据处理函数
process_and_save_data(HS_list, freq_list, bands_list, base_path, save_path)
# Out:
# cue trails shape for theta: (312, 256, 380), cue trails shape for bandtheta: (312, 256, 380)
# cue trails shape for alpha: (312, 256, 380), cue trails shape for bandalpha: (312, 256, 380)
# cue trails shape for beta1: (312, 256, 380), cue trails shape for bandbeta1: (312, 256, 380)
# cue trails shape for beta2: (312, 256, 380), cue trails shape for bandbeta2: (312, 256, 380)
# cue trails shape for low gamma: (312, 256, 380), cue trails shape for bandlow gamma: (312, 256, 380)
# cue trails shape for high gamma: (312, 256, 380), cue trails shape for bandhigh gamma: (312, 256, 380)
# Processed and saved data for HS68, freq 400
# cue trails shape for theta: (336, 256, 380), cue trails shape for bandtheta: (336, 256, 380)
# cue trails shape for alpha: (336, 256, 380), cue trails shape for bandalpha: (336, 256, 380)
# cue trails shape for beta1: (336, 256, 380), cue trails shape for bandbeta1: (336, 256, 380)
# cue trails shape for beta2: (336, 256, 380), cue trails shape for bandbeta2: (336, 256, 380)
# cue trails shape for low gamma: (336, 256, 380), cue trails shape for bandlow gamma: (336, 256, 380)
# cue trails shape for high gamma: (336, 256, 380), cue trails shape for bandhigh gamma: (336, 256, 380)
# Processed and saved data for HS69, freq 400
# cue trails shape for theta: (360, 256, 380), cue trails shape for bandtheta: (360, 256, 380)
# cue trails shape for alpha: (360, 256, 380), cue trails shape for bandalpha: (360, 256, 380)
# cue trails shape for beta1: (360, 256, 380), cue trails shape for bandbeta1: (360, 256, 380)
# cue trails shape for beta2: (360, 256, 380), cue trails shape for bandbeta2: (360, 256, 380)
# cue trails shape for low gamma: (360, 256, 380), cue trails shape for bandlow gamma: (360, 256, 380)
# cue trails shape for high gamma: (360, 256, 380), cue trails shape for bandhigh gamma: (360, 256, 380)
# Processed and saved data for HS75, freq 400
# cue trails shape for theta: (309, 256, 380), cue trails shape for bandtheta: (309, 256, 380)
# cue trails shape for alpha: (309, 256, 380), cue trails shape for bandalpha: (309, 256, 380)
# cue trails shape for beta1: (309, 256, 380), cue trails shape for bandbeta1: (309, 256, 380)
# cue trails shape for beta2: (309, 256, 380), cue trails shape for bandbeta2: (309, 256, 380)
# cue trails shape for low gamma: (309, 256, 380), cue trails shape for bandlow gamma: (309, 256, 380)
# cue trails shape for high gamma: (309, 256, 380), cue trails shape for bandhigh gamma: (309, 256, 380)
# Processed and saved data for HS79, freq 400
# cue trails shape for theta: (297, 256, 380), cue trails shape for bandtheta: (297, 256, 380)
# cue trails shape for alpha: (297, 256, 380), cue trails shape for bandalpha: (297, 256, 380)
# cue trails shape for beta1: (297, 256, 380), cue trails shape for bandbeta1: (297, 256, 380)
# cue trails shape for beta2: (297, 256, 380), cue trails shape for bandbeta2: (297, 256, 380)
# cue trails shape for low gamma: (297, 256, 380), cue trails shape for bandlow gamma: (297, 256, 380)
# cue trails shape for high gamma: (297, 256, 380), cue trails shape for bandhigh gamma: (297, 256, 380)
# Processed and saved data for HS82, freq 400
# cue trails shape for theta: (357, 256, 380), cue trails shape for bandtheta: (357, 256, 380)
# cue trails shape for alpha: (357, 256, 380), cue trails shape for bandalpha: (357, 256, 380)
# cue trails shape for beta1: (357, 256, 380), cue trails shape for bandbeta1: (357, 256, 380)
# cue trails shape for beta2: (357, 256, 380), cue trails shape for bandbeta2: (357, 256, 380)
# cue trails shape for low gamma: (357, 256, 380), cue trails shape for bandlow gamma: (357, 256, 380)
# cue trails shape for high gamma: (357, 256, 380), cue trails shape for bandhigh gamma: (357, 256, 380)
# Processed and saved data for HS83, freq 400
# cue trails shape for theta: (360, 256, 380), cue trails shape for bandtheta: (360, 256, 380)
# cue trails shape for alpha: (360, 256, 380), cue trails shape for bandalpha: (360, 256, 380)
# cue trails shape for beta1: (360, 256, 380), cue trails shape for bandbeta1: (360, 256, 380)
# cue trails shape for beta2: (360, 256, 380), cue trails shape for bandbeta2: (360, 256, 380)
# cue trails shape for low gamma: (360, 256, 380), cue trails shape for bandlow gamma: (360, 256, 380)
# cue trails shape for high gamma: (360, 256, 380), cue trails shape for bandhigh gamma: (360, 256, 380)
# Processed and saved data for HS84, freq 400
# cue trails shape for theta: (360, 256, 380), cue trails shape for bandtheta: (360, 256, 380)
# cue trails shape for alpha: (360, 256, 380), cue trails shape for bandalpha: (360, 256, 380)
# cue trails shape for beta1: (360, 256, 380), cue trails shape for bandbeta1: (360, 256, 380)
# cue trails shape for beta2: (360, 256, 380), cue trails shape for bandbeta2: (360, 256, 380)
# cue trails shape for low gamma: (360, 256, 380), cue trails shape for bandlow gamma: (360, 256, 380)
# cue trails shape for high gamma: (360, 256, 380), cue trails shape for bandhigh gamma: (360, 256, 380)
# Processed and saved data for HS85, freq 400
# cue trails shape for theta: (360, 256, 380), cue trails shape for bandtheta: (360, 256, 380)
# cue trails shape for alpha: (360, 256, 380), cue trails shape for bandalpha: (360, 256, 380)
# cue trails shape for beta1: (360, 256, 380), cue trails shape for bandbeta1: (360, 256, 380)
# cue trails shape for beta2: (360, 256, 380), cue trails shape for bandbeta2: (360, 256, 380)
# cue trails shape for low gamma: (360, 256, 380), cue trails shape for bandlow gamma: (360, 256, 380)
# cue trails shape for high gamma: (360, 256, 380), cue trails shape for bandhigh gamma: (360, 256, 380)
# Processed and saved data for HS86, freq 400
